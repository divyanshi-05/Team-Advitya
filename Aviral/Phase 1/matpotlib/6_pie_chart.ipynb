# %%
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline

# %%
exp_vals=[1400,600,410,250]
exp_labels=["home rent","food", "phone bill","other"]

# %%
plt.pie(exp_vals,labels=exp_labels,radius=1.5, autopct='%0.2f%%')
plt.show()
plt.savefig('6_pie_chart.png')
